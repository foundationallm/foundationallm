# %%
#pre-requisites

# 1. You need access to the key vault to enumerate the values.
# 2. Set the environment variable foundationallm-app-configuration-uri.
# 3. You must be able to gain access to the service endpoints to verify them.

# %%
#install packages
# !pip install msal
# !pip install azure-identity
# !pip install azure-storage-blob
# !pip install azure.ai.contentsafety
# !pip install azure-search-documents
# !pip install azure-cosmos
# !pip install azure-applicationinsights
# !pip install azure.monitor

# %%
import os
import sys

#import the FLLM SDK
sys.path.append('C:/github/solliancenet/foundationallm/src/python/PythonSDK')

from foundationallm.config import Configuration

#set the connection string if needed...
#os.environ['foundationallm-app-configuration-uri'] = ''

# %%
#get app configuration connections string
config = Configuration()

# %%
def verify_app_config():

    #check all config values are set and formatted properly.
    keys = [
    "FoundationaLLM:APIs:AgentFactoryAPI:APIUrl",
    "FoundationaLLM:APIs:AgentHubAPI:APIUrl",
    "FoundationaLLM:APIs:CoreAPI:APIUrl",
    "FoundationaLLM:APIs:DataSourceHubAPI:APIUrl",
    "FoundationaLLM:APIs:GatekeeperAPI:APIUrl",
    "FoundationaLLM:APIs:LangChainAPI:APIUrl",
    "FoundationaLLM:APIs:PromptHubAPI:APIUrl",
    "FoundationaLLM:APIs:SemanticKernelAPI:APIUrl",
    "FoundationaLLM:APIs:CoreAPI:AppInsightsConnectionString",
    "FoundationaLLM:APIs:GatekeeperAPI:AppInsightsConnectionString",
    "FoundationaLLM:APIs:AgentFactoryAPI:AppInsightsConnectionString",
    "FoundationaLLM:APIs:AgentFactoryAPI:APIKey",
    "FoundationaLLM:APIs:AgentHubAPI:APIKey",
    "FoundationaLLM:APIs:DataSourceHubAPI:APIKey",
    "FoundationaLLM:APIs:GatekeeperAPI:APIKey",
    "FoundationaLLM:APIs:LangChainAPI:APIKey",
    "FoundationaLLM:APIs:PromptHubAPI:APIKey",
    "FoundationaLLM:APIs:SemanticKernelAPI:APIKey",
    "FoundationaLLM:AgentHub:AgentMetadata:StorageContainer",
    "FoundationaLLM:AgentHub:StorageManager:BlobStorage:ConnectionString",
    "FoundationaLLM:AzureContentSafety:APIKey",
    "FoundationaLLM:AzureContentSafety:APIUrl",
    "FoundationaLLM:AzureContentSafety:HateSeverity",
    "FoundationaLLM:AzureContentSafety:SelfHarmSeverity",
    "FoundationaLLM:AzureContentSafety:SexualSeverity",
    "FoundationaLLM:AzureContentSafety:ViolenceSeverity",
    "FoundationaLLM:AzureOpenAI:API:Completions:DeploymentName",
    "FoundationaLLM:AzureOpenAI:API:Completions:MaxTokens",
    "FoundationaLLM:AzureOpenAI:API:Completions:ModelName",
    "FoundationaLLM:AzureOpenAI:API:Completions:ModelVersion",
    "FoundationaLLM:AzureOpenAI:API:Completions:Temperature",
    "FoundationaLLM:AzureOpenAI:API:Embeddings:DeploymentName",
    "FoundationaLLM:AzureOpenAI:API:Embeddings:MaxTokens",
    "FoundationaLLM:AzureOpenAI:API:Embeddings:ModelName",
    "FoundationaLLM:AzureOpenAI:API:Embeddings:Temperature",
    "FoundationaLLM:AzureOpenAI:API:Endpoint",
    "FoundationaLLM:AzureOpenAI:API:Key",
    "FoundationaLLM:AzureOpenAI:API:Version",
    "FoundationaLLM:BlobStorage:ConnectionString",
    "FoundationaLLM:BlobStorageMemorySource:BlobStorageConnection",
    "FoundationaLLM:BlobStorageMemorySource:ConfigBlobStorageContainer",
    "FoundationaLLM:BlobStorageMemorySource:ConfigFilePath",
    "FoundationaLLM:Branding:AccentColor",
    "FoundationaLLM:Branding:BackgroundColor",
    "FoundationaLLM:Branding:CompanyName",
    "FoundationaLLM:Branding:FavIconUrl",
    "FoundationaLLM:Branding:KioskMode",
    "FoundationaLLM:Branding:LogoText",
    "FoundationaLLM:Branding:LogoUrl",
    "FoundationaLLM:Branding:PageTitle",
    "FoundationaLLM:Branding:PrimaryColor",
    "FoundationaLLM:Branding:PrimaryTextColor",
    "FoundationaLLM:Branding:SecondaryColor",
    "FoundationaLLM:Branding:SecondaryTextColor",
    "FoundationaLLM:Chat:Entra:CallbackPath",
    "FoundationaLLM:Chat:Entra:ClientId",
    "FoundationaLLM:Chat:Entra:ClientSecret",
    "FoundationaLLM:Chat:Entra:Instance",
    "FoundationaLLM:Chat:Entra:Scopes",
    "FoundationaLLM:Chat:Entra:TenantId",
    "FoundationaLLM:CognitiveSearch:ConfigBlobStorageConnection",
    "FoundationaLLM:CognitiveSearch:EndPoint",
    "FoundationaLLM:CognitiveSearch:IndexName",
    "FoundationaLLM:CognitiveSearch:Key",
    "FoundationaLLM:CognitiveSearch:MaxVectorSearchResults",
    "FoundationaLLM:CognitiveSearchMemorySource:BlobStorageConnection",
    "FoundationaLLM:CognitiveSearchMemorySource:ConfigBlobStorageContainer",
    "FoundationaLLM:CognitiveSearchMemorySource:ConfigFilePath",
    "FoundationaLLM:CognitiveSearchMemorySource:EndPoint",
    "FoundationaLLM:CognitiveSearchMemorySource:IndexName",
    "FoundationaLLM:CognitiveSearchMemorySource:Key",
    "FoundationaLLM:CoreAPI:Entra:CallbackPath",
    "FoundationaLLM:CoreAPI:Entra:ClientId",
    "FoundationaLLM:CoreAPI:Entra:ClientSecret",
    "FoundationaLLM:CoreAPI:Entra:Instance",
    "FoundationaLLM:CoreAPI:Entra:Scopes",
    "FoundationaLLM:CoreAPI:Entra:TenantId",
    "FoundationaLLM:CosmosDB:ChangeFeedLeaseContainer",
    "FoundationaLLM:CosmosDB:Containers",
    "FoundationaLLM:CosmosDB:Database",
    "FoundationaLLM:CosmosDB:Endpoint",
    "FoundationaLLM:CosmosDB:Key",
    "FoundationaLLM:CosmosDB:MonitoredContainers",
    "FoundationaLLM:DataSourceHub:DataSourceMetadata:StorageContainer",
    "FoundationaLLM:DataSourceHub:StorageManager:BlobStorage:ConnectionString",
    "FoundationaLLM:DurableSystemPrompt:BlobStorageConnection",
    "FoundationaLLM:DurableSystemPrompt:BlobStorageContainer",
    "FoundationaLLM:LangChain:CSVFile:URL",
    "FoundationaLLM:LangChain:SQLDatabase:TestDB:Password",
    "FoundationaLLM:LangChain:Summary:MaxTokens",
    "FoundationaLLM:LangChain:Summary:ModelName",
    "FoundationaLLM:LangChainAPI:Key",
    "FoundationaLLM:OpenAI:API:Endpoint",
    "FoundationaLLM:OpenAI:API:Key",
    "FoundationaLLM:OpenAI:API:Temperature",
    "FoundationaLLM:PromptHub:PromptMetadata:StorageContainer",
    "FoundationaLLM:PromptHub:StorageManager:BlobStorage:ConnectionString",
    "FoundationaLLM:Refinement",
    "FoundationaLLM:SemanticKernelAPI:OpenAI.ChatCompletionPromptName",
    "FoundationaLLM:SemanticKernelAPI:OpenAI.CompletionsDeployment",
    "FoundationaLLM:SemanticKernelAPI:OpenAI.CompletionsDeploymentMaxTokens",
    "FoundationaLLM:SemanticKernelAPI:OpenAI.EmbeddingsDeployment",
    "FoundationaLLM:SemanticKernelAPI:OpenAI.EmbeddingsDeploymentMaxTokens",
    "FoundationaLLM:SemanticKernelAPI:OpenAI.Endpoint",
    "FoundationaLLM:SemanticKernelAPI:OpenAI.PromptOptimization.CompletionsMaxTokens",
    "FoundationaLLM:SemanticKernelAPI:OpenAI.PromptOptimization.CompletionsMinTokens",
    "FoundationaLLM:SemanticKernelAPI:OpenAI.PromptOptimization.MemoryMaxTokens",
    "FoundationaLLM:SemanticKernelAPI:OpenAI.PromptOptimization.MemoryMinTokens",
    "FoundationaLLM:SemanticKernelAPI:OpenAI.PromptOptimization.MessagesMaxTokens",
    "FoundationaLLM:SemanticKernelAPI:OpenAI.PromptOptimization.MessagesMinTokens",
    "FoundationaLLM:SemanticKernelAPI:OpenAI.PromptOptimization.SystemMaxTokens",
    "FoundationaLLM:SemanticKernelAPI:OpenAI.ShortSummaryPromptName",
    "FoundationaLLM:SemanticKernelAPI:OpenAI:Key"
    ]

    for key in keys:

        try:
            value = config.get_value(key, use_retry=False)

            if ( value == None or value == '' ):
                print('ERROR: Key: ' + key + ' is not set.')
        except Exception as e:
            print('ERROR: Key: ' + key + ' is not set.')

# %%
verify_app_config()

# %%
def verify_container(db, container_name):
    try:
        container = db.get_container_client(container_name)
        container.read()
    except Exception as e:
        print('ERROR: Container: ' + container_name + ' does not exist.')

def verify_cosmosdb():

    from azure.cosmos import CosmosClient
    from azure.core.credentials import AzureKeyCredential

    #check connectivity
    lease_container_name = config.get_value("FoundationaLLM:CosmosDB:ChangeFeedLeaseContainer", use_retry=False)
    containers = config.get_value("FoundationaLLM:CosmosDB:Containers", use_retry=False)
    database_name = config.get_value("FoundationaLLM:CosmosDB:Database", use_retry=False)
    monitored_containers = config.get_value("FoundationaLLM:CosmosDB:MonitoredContainers", use_retry=False)

    endpoint = config.get_value("FoundationaLLM:CosmosDB:Endpoint", use_retry=False)
    key = config.get_value("FoundationaLLM:CosmosDB:Key", use_retry=False)

    client = CosmosClient(url=endpoint, credential={'masterKey': key} )

    #check database exits
    try:
        db = client.get_database_client(database_name)
        db.read()

        #check containers exist
        for container_name in containers.split(','):
            verify_container(db, container_name)

        verify_container(db, lease_container_name)

        for container_name in monitored_containers.split(','):
            verify_container(db, container_name)

    except Exception as e:
        print('ERROR: Database: ' + database_name + ' does not exist.')

# %%
verify_cosmosdb()

# %%
def verify_app_insights(connection_string):

    from azure.identity  import  DefaultAzureCredential
    from azure.applicationinsights  import  ApplicationInsightsDataClient
    from azure.applicationinsights.models.query_body import QueryBody
    from datetime import datetime, timezone
    
    items = dict(item.split("=") for item in connection_string.split(";"))
    
    app_id = items['InstrumentationKey']
    endpoint = items['IngestionEndpoint']

    from azure.monitor.query import LogsQueryClient, MetricsQueryClient

    credential = DefaultAzureCredential()

    client = ApplicationInsightsDataClient(credential, base_url=endpoint)

    logs_client = LogsQueryClient(credential)
    metrics_client = MetricsQueryClient(credential)
    
    query = """
    traces
    | limit 10
    """

    timespan = "PT24H"

    raw_data = client.query.execute(app_id, body=QueryBody(query=query, timespan=timespan))
    
    print(raw_data)

    #start_time=datetime(2021, 7, 2, tzinfo=timezone.utc)
    #end_time=datetime(2021, 7, 4, tzinfo=timezone.utc)

    #response = logs_client.query_workspace(workspace_id=app_id,query=query,timespan=(start_time, end_time))
    
    #print(response)

# %%
verify_app_insights(config.get_value("FoundationaLLM:APIs:CoreAPI:AppInsightsConnectionString", use_retry=False))
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# c:\github\solliancenet\foundationallm\deploy\notebooks\verify_deploy.ipynb Cell 10 line 1
# ----> <a href='vscode-notebook-cell:/c%3A/github/solliancenet/foundationallm/deploy/notebooks/verify_deploy.ipynb#X51sZmlsZQ%3D%3D?line=0'>1</a> verify_app_insights(config.get_value("FoundationaLLM:APIs:CoreAPI:AppInsightsConnectionString", use_retry=False))
#
# c:\github\solliancenet\foundationallm\deploy\notebooks\verify_deploy.ipynb Cell 10 line 2
#      <a href='vscode-notebook-cell:/c%3A/github/solliancenet/foundationallm/deploy/notebooks/verify_deploy.ipynb#X51sZmlsZQ%3D%3D?line=21'>22</a> query = """
#      <a href='vscode-notebook-cell:/c%3A/github/solliancenet/foundationallm/deploy/notebooks/verify_deploy.ipynb#X51sZmlsZQ%3D%3D?line=22'>23</a> traces
#      <a href='vscode-notebook-cell:/c%3A/github/solliancenet/foundationallm/deploy/notebooks/verify_deploy.ipynb#X51sZmlsZQ%3D%3D?line=23'>24</a> | limit 10
#      <a href='vscode-notebook-cell:/c%3A/github/solliancenet/foundationallm/deploy/notebooks/verify_deploy.ipynb#X51sZmlsZQ%3D%3D?line=24'>25</a> """
#      <a href='vscode-notebook-cell:/c%3A/github/solliancenet/foundationallm/deploy/notebooks/verify_deploy.ipynb#X51sZmlsZQ%3D%3D?line=26'>27</a> timespan = "PT24H"
# ---> <a href='vscode-notebook-cell:/c%3A/github/solliancenet/foundationallm/deploy/notebooks/verify_deploy.ipynb#X51sZmlsZQ%3D%3D?line=28'>29</a> raw_data = client.query.execute(app_id, body=QueryBody(query=query, timespan=timespan))
#      <a href='vscode-notebook-cell:/c%3A/github/solliancenet/foundationallm/deploy/notebooks/verify_deploy.ipynb#X51sZmlsZQ%3D%3D?line=30'>31</a> print(raw_data)
#
# File ~\AppData\Roaming\Python\Python310\site-packages\azure\applicationinsights\operations\query_operations.py:84, in QueryOperations.execute(self, app_id, body, custom_headers, raw, **operation_config)
#      82 # Construct and send request
#      83 request = self._client.post(url, query_parameters, header_parameters, body_content)
# ---> 84 response = self._client.send(request, stream=False, **operation_config)
#      86 if response.status_code not in [200]:
#      87     raise models.ErrorResponseException(self._deserialize, response)
#
# File ~\AppData\Roaming\Python\Python310\site-packages\msrest\service_client.py:336, in ServiceClient.send(self, request, headers, content, **kwargs)
#     334 kwargs.setdefault('stream', True)
#     335 try:
# --> 336     pipeline_response = self.config.pipeline.run(request, **kwargs)
#     337     # There is too much thing that expects this method to return a "requests.Response"
#     338     # to break it in a compatible release.
#     339     # Also, to be pragmatic in the "sync" world "requests" rules anyway.
#     340     # However, attach the Universal HTTP response
#     341     # to get the streaming generator.
#     342     response = pipeline_response.http_response.internal_response
#
# File ~\AppData\Roaming\Python\Python310\site-packages\msrest\pipeline\__init__.py:197, in Pipeline.run(self, request, **kwargs)
#     195 pipeline_request = Request(request, context)  # type: Request[HTTPRequestType]
#     196 first_node = self._impl_policies[0] if self._impl_policies else self._sender
# --> 197 return first_node.send(pipeline_request, **kwargs)
#
# File ~\AppData\Roaming\Python\Python310\site-packages\msrest\pipeline\__init__.py:150, in _SansIOHTTPPolicyRunner.send(self, request, **kwargs)
#     148 self._policy.on_request(request, **kwargs)
#     149 try:
# --> 150     response = self.next.send(request, **kwargs)
#     151 except Exception:
#     152     if not self._policy.on_exception(request, **kwargs):
#
# File ~\AppData\Roaming\Python\Python310\site-packages\msrest\pipeline\requests.py:65, in RequestsCredentialsPolicy.send(self, request, **kwargs)
#      63 session = request.context.session
#      64 try:
# ---> 65     self._creds.signed_session(session)
#      66 except TypeError: # Credentials does not support session injection
#      67     _LOGGER.warning("Your credentials class does not support session injection. Performance will not be at the maximum.")
#
# AttributeError: 'DefaultAzureCredential' object has no attribute 'signed_session'

# %%
verify_app_insights(config.get_value("FoundationaLLM:APIs:GatekeeperAPI:AppInsightsConnectionString", use_retry=False))

# %%
verify_app_insights(config.get_value("FoundationaLLM:APIs:AgentFactoryAPI:AppInsightsConnectionString", use_retry=False))

# %%
def verify_cogsearch():

    from azure.core.credentials import AzureKeyCredential
    from azure.search.documents import SearchClient

    #check connectivity
    key = config.get_value("FoundationaLLM:CognitiveSearch:Key", use_retry=False)
    endpoint = config.get_value("FoundationaLLM:CognitiveSearch:EndPoint", use_retry=False)
    index_name = config.get_value("FoundationaLLM:CognitiveSearch:IndexName", use_retry=False)

    credential = AzureKeyCredential(key)

    client = SearchClient(endpoint=endpoint,
                        index_name=index_name,
                        credential=credential)
    
    results = client.search(search_text="luxury")

    print(results)

# %%
verify_cogsearch()

# %%
def verify_contentsafety():

    from azure.ai.contentsafety import ContentSafetyClient
    from azure.core.credentials import AzureKeyCredential
    from azure.core.exceptions import HttpResponseError
    from azure.ai.contentsafety.models import AnalyzeImageOptions, ImageData, TextBlockItem, AnalyzeTextOptions

    #check connectivity
    endpoint = config.get_value("FoundationaLLM:AzureContentSafety:APIUrl", use_retry=False)
    key = config.get_value("FoundationaLLM:AzureContentSafety:APIKey", use_retry=False)

    client = ContentSafetyClient(endpoint, AzureKeyCredential(key))    

    td = TextBlockItem()
    td.text = "Hello World"

    res = client.analyze_text(td)

    print(res)

# %%
verify_contentsafety()

# %%
def verify_storage_containers(connection_string, containers):

    #check connectivity
    from azure.storage.blob import BlobServiceClient, BlobClient, ContainerClient
    from azure.identity import ClientSecretCredential, DefaultAzureCredential

    # Create the BlobServiceClient object
    blob_service_client = BlobServiceClient.from_connection_string(connection_string)
    
    #blob_service_client = BlobServiceClient(account_url, credential=default_credential)

    #check storage containers exist
    for container_name in containers:
        container_client = blob_service_client.get_container_client(container_name)

# %%
connection_string = config.get_value("FoundationaLLM:AgentHub:StorageManager:BlobStorage:ConnectionString", use_retry=False)
containers = ['agents'] #config.get_value("agents")

verify_storage_containers(connection_string, containers)

# %%
connection_string = config.get_value("FoundationaLLM:BlobStorageMemorySource:BlobStorageConnection", use_retry=False)
containers = ['memory-source'] #config.get_value("agents")

verify_storage_containers(connection_string, containers)

# %%
connection_string = config.get_value("FoundationaLLM:DataSourceHub:StorageManager:BlobStorage:ConnectionString", use_retry=False)
containers = ['data-sources'] #config.get_value("agents")

verify_storage_containers(connection_string, containers)

# %%
connection_string = config.get_value("FoundationaLLM:DurableSystemPrompt:BlobStorageConnection", use_retry=False)
containers = ['system-prompt'] #config.get_value("agents")

verify_storage_containers(connection_string, containers)

# %%
connection_string = config.get_value("FoundationaLLM:PromptHub:StorageManager:BlobStorage:ConnectionString", use_retry=False)
containers = ['prompts'] #config.get_value("agents")

verify_storage_containers(connection_string, containers)

# %%
def verify_openai(openai_type, endpoint, key, models):

    #check connectivity
    import openai

    if ( openai_type == "azure_ad"):
        from azure.identity import DefaultAzureCredential
        credential = DefaultAzureCredential()
        token = credential.get_token("https://cognitiveservices.azure.com/.default")   

        openai.api_type = "azure_ad"
        openai.api_key = token.token
        openai.api_base = endpoint
        openai.api_version = "2023-05-15"  # subject to change
    
    if (openai_type == "azure"):
        openai.api_type = "azure"
        openai.api_key = key
        openai.api_base = endpoint
        openai.api_version = "2023-05-15"  # subject to change

    if (openai_type == "openai"):
        openai.api_type = "openai"
        openai.api_key = key
        openai.api_base = endpoint
        openai.api_version = "2023-05-15"  # subject to change

    prompt = 'hello world'
    messages = ['hello', 'world']
    input = 'hello world'

    for model in models:
        #ensure models exist
        name = model['name']
        type = model['type']
        sub_model = model['model']

        if ( type == 'completion'):

            if (openai_type == "azure" or openai_type == "azure_ad"):
                openai.Deployment.retrieve(id=name)
            else:
                openai.Completion.retrieve(name)
        
        if ( type == 'chat-completion'):

            if (openai_type == "azure" or openai_type == "azure_ad"):
                openai.Deployment.retrieve(id=name)
            else:
                openai.ChatCompletion.retrieve(name)

        if ( type == "embedding"):

            if (openai_type == "azure" or openai_type == "azure_ad"):
                openai.Deployment.retrieve(id=name)
            else:
                openai.Embedding.retrieve(name)

# %%
endpoint = config.get_value("FoundationaLLM:OpenAI:API:Endpoint", use_retry=False)
key = config.get_value("FoundationaLLM:OpenAI:API:Key", use_retry=False)

models = [
    {
        'type' : 'completion',
        'model' : 'gpt-35-turbo',
        'name' : 'completions'
    },
    {
        'type' : 'completion',
        'model' : 'text-davinci-003',
        'name' : 'completion'
    },
    #{
    #    'type' : 'chat-completion',
    #    'model' : '',
    #    'name' : ''
    #},
    {
        'type' : 'embedding',
        'model' : 'text-embedding-ada-002',
        'name' : 'embeddings'
    }
]

verify_openai('azure_ad', endpoint, key, models)

# %%
endpoint = config.get_value("FoundationaLLM:AzureOpenAI:API:Endpoint", use_retry=False)
key = config.get_value("FoundationaLLM:AzureOpenAI:API:Key", use_retry=False)
api_version = config.get_value("FoundationaLLM:AzureOpenAI:API:Version", use_retry=False)

models = [
    {
        'type' : 'completion',
        'model' : 'gpt-35-turbo',
        'name' : 'completions'
    },
    {
        'type' : 'completion',
        'model' : 'text-davinci-003',
        'name' : 'completion'
    },
    #{
    #    'type' : 'chat-completion',
    #    'model' : '',
    #    'name' : ''
    #},
    {
        'type' : 'embedding',
        'model' : 'text-embedding-ada-002',
        'name' : 'embeddings'
    }
]

verify_openai('openai', endpoint, key, models)

# %%
def verify_azure_entra_ui():
    
    from msal import PublicClientApplication
    from azure.identity import ClientSecretCredential, DefaultAzureCredential

    #verify the chat UI app
    client_id = config.get_value('FoundationaLLM:Chat:Entra:ClientId', use_retry=False)
    client_secret = config.get_value('FoundationaLLM:Chat:Entra:ClientSecret', use_retry=False)
    tenant_id = config.get_value('FoundationaLLM:Chat:Entra:TenantId', use_retry=False)
    scope = f'{client_id}/.default'
    
    #check application exists
    app = PublicClientApplication(client_id, authority=f"https://login.microsoftonline.com/{tenant_id}")

    accounts = app.get_accounts()

    if ( len(accounts) > 0):
        result = app.acquire_token_silent(scope, account=accounts[0])

    #validate the client secret
    credential = ClientSecretCredential(
       tenant_id=tenant_id,
       client_id=client_id,
       client_secret=client_secret,
   )
    
    token = credential.get_token(scope)

    print(token)

    return token.token

# %%
verify_azure_entra_ui()

# %%
def verify_azure_entra_core():
    
    from msal import PublicClientApplication
    from azure.identity import ClientSecretCredential, DefaultAzureCredential

    #verify the CoreAPI app
    client_id = config.get_value('FoundationaLLM:CoreAPI:Entra:ClientId', use_retry=False)
    client_secret = config.get_value('FoundationaLLM:CoreAPI:Entra:ClientSecret', use_retry=False)
    tenant_id = config.get_value('FoundationaLLM:CoreAPI:Entra:TenantId', use_retry=False)
    scope = config.get_value('FoundationaLLM:CoreAPI:Entra:Scopes', use_retry=False)
    
    #check application exists
    app = PublicClientApplication(client_id, authority=f"https://login.microsoftonline.com/{tenant_id}")

    accounts = app.get_accounts()

    if ( len(accounts) > 0):
        result = app.acquire_token_silent(scope, account=accounts[0])

    #validate the client secret
    credential = ClientSecretCredential(
       tenant_id=tenant_id,
       client_id=client_id,
       client_secret=client_secret,
   )
    
    token = credential.get_token(f'{client_id}/.default')

    print(token)

    return token.token

# %%
verify_azure_entra_core()

# %%
def verify_services():

    verify_chatui()
    verify_coreapi()
    verify_gatekeeperapi()
    verify_agentfactoryapi()
    verify_agenthubapi()
    verify_prompthubapi()
    verify_datasourcehubapi()
    verify_langchainapi()

def verify_chatui():

    #get auth bearer token..
    token = verify_azure_entra_ui()

    url = config.get_value('FoundationaLLM:Chat:Entra:CallbackPath', use_retry=False)
    
    #check connectivity
    import requests

    res = requests.get(url)

def verify_coreapi():

    token = verify_azure_entra_core()

    url = config.get_value('FoundationaLLM:APIs:CoreAPI:APIUrl', use_retry=False)
    key = config.get_value('FoundationaLLM:APIs:CoreAPI:APIKey', use_retry=False)

    #check connectivity
    import requests

    myobj = {'somekey': 'somevalue'}

    headers = {
        'X-API-KEY': key,
    }

    res = requests.post(url, json = myobj, headers=headers)

def verify_gatekeeperapi():

    url = config.get_value('FoundationaLLM:APIs:GatekeeperAPI:APIUrl', use_retry=False)
    key = config.get_value('FoundationaLLM:APIs:GatekeeperAPI:APIKey', use_retry=False)

    #check connectivity
    import requests

    myobj = {'somekey': 'somevalue'}

    headers = {
        'X-API-KEY': key,
    }

    res = requests.post(url, json = myobj, headers=headers)

def verify_agentfactoryapi():

    url = config.get_value('FoundationaLLM:APIs:AgentFactoryAPI:APIUrl', use_retry=False)
    key = config.get_value('FoundationaLLM:APIs:AgentFactoryAPI:APIKey', use_retry=False)

    #check connectivity
    import requests

    myobj = {'somekey': 'somevalue'}

    headers = {
        'X-API-KEY': key,
    }

    res = requests.post(url, json = myobj, headers=headers)

def verify_semnatickernelapi():

    url = config.get_value('FoundationaLLM:APIs:SemanticKernelAPI:APIUrl', use_retry=False)
    key = config.get_value('FoundationaLLM:APIs:SemanticKernelAPI:APIKey', use_retry=False)

    #check connectivity
    import requests

    myobj = {'somekey': 'somevalue'}

    headers = {
        'X-API-KEY': key,
    }

    res = requests.post(url, json = myobj, headers=headers)

def verify_agenthubapi():

    url = config.get_value('FoundationaLLM:APIs:AgentHubAPI:APIUrl', use_retry=False)
    key = config.get_value('FoundationaLLM:APIs:AgentHubAPI:APIKey', use_retry=False)

    #check connectivity
    import requests

    myobj = {
        "user_prompt": "hello",
        "user_context": "",
        "message+history": [
        ]
    }

    headers = {
        'X-API-KEY': key,
    }

    res = requests.post(url, json = myobj, headers=headers)

def verify_gatekeeperapi():

    url = config.get_value('FoundationaLLM:APIs:GatekeeperAPI:APIUrl', use_retry=False)
    key = config.get_value('FoundationaLLM:APIs:GatekeeperAPI:APIKey', use_retry=False)

    #check connectivity
    import requests

    myobj = {
        "user_prompt": "hello",
        "user_context": "",
        "message+history": [
        ]
    }

    headers = {
        'X-API-KEY': key,
    }

    res = requests.post(f'{url}/Orchestration/completion?api-version=1.0', json = myobj, headers=headers)

def verify_prompthubapi():

    url = config.get_value('FoundationaLLM:APIs:PromptHubAPI:APIUrl', use_retry=False)
    key = config.get_value('FoundationaLLM:APIs:PromptHubAPI:APIKey', use_retry=False)

    #check connectivity
    import requests

    myobj = {"agent_name":"weather"}

    headers = {
        'X-API-KEY': key,
    }

    res = requests.post(f'{url}/resolve', json = myobj, headers=headers)

def verify_datasourcehubapi():

    url = config.get_value('FoundationaLLM:APIs:DataSourceHubAPI:APIUrl', use_retry=False)
    key = config.get_value('FoundationaLLM:APIs:DataSourceHubAPI:APIKey', use_retry=False)

    #check connectivity
    import requests

    myobj = {
        "data_sources":["about-solliance"]
    }

    headers = {
        'X-API-KEY': key,
    }

    res = requests.post(f'{url}/resolve', json = myobj, headers=headers)

def verify_langchainapi():

    url = config.get_value('FoundationaLLM:APIs:LangChainAPI:APIUrl', use_retry=False)
    key = config.get_value('FoundationaLLM:APIs:LangChainAPI:APIKey', use_retry=False)

    #check connectivity
    import requests

    post = {
    "user_prompt": "A group of Senate Republicans vowed to block non-spending-related bills in a letter sent to Sen. Majority leader Chuck Schumer, D-N.Y., on Wednesday, as the upper chamber breaks for a Columbus Day recess until next week.\nThe upper chamber has until November 17 until the current Continuing Resolution (CR) expires, and Congress will need to come together again to agree on a government spending package for the next fiscal year.\nThe senators fear that if the spending legislation gets put on the back burner behind other bills, Democrats in the upper chamber will try to jam through another omnibus spending package.\"Today, despite being past the September 30th deadline, with the Senate Appropriations Committee having already passed each of the 12 bills for our chamber, we have the best opportunity in decades to complete our work,\" Sen. Rick Scott, R-Fla., said in the letter.\nSenate Whip John Thune, R-S.D., Sen. John Cornyn, R-Texas, Senate Republican Conference Chairman John Barrasso of Wyoming, Sen. Joni Ernst, R-Iowa, GOP Conference Vice Chairwoman Shelley Moore-Capito of West Virginia, Sen. Ted Cruz, R-Texas, and Sen. Tommy Tuberville, R-Ala., also signed the letter, among others.",
    "agent": {
        "name": "summarizer",
        "type": "summary",
        "description": "Useful for summarizing input text based on a set of rules.",
        "prompt_template": "Write a concise two-word summary of the following:\n\"{text}\"\nCONCISE SUMMARY IN TWO WORDS:"
    },
    "language_model": {
        "type": "openai",
        "provider": "microsoft",
        "temperature": 0.5,
        "use_chat": True
    }
}

    headers = {
        'X-API-KEY': key,
    }

    res = requests.post(f'{url}/orchestration/completion', json = post, headers=headers)

# %%
verify_langchainapi()

# %%
verify_datasourcehubapi()

# %%
verify_prompthubapi()

# %%
verify_gatekeeperapi()

# %%
verify_agenthubapi()

# %%
verify_semnatickernelapi()

# %%
verify_agentfactoryapi()
